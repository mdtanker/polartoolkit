# %% [markdown]
# # Basement Topography
# **Description:**  A grid of crystalline basement topography. Currently only available for a portion of West Antarctica.
#
# **Dataset DOI:** 10.1594/PANGAEA.941238
#
# **Associated paper:** Basement Topography and Sediment Thickness Beneath Antarctica's Ross Ice Shelf. DOI: 10.1029/2021GL097371

# %%
# %%capture
# %load_ext autoreload
# %autoreload 2

from polartoolkit import fetch, maps, utils

# %%
data = fetch.basement(
    # available options
    # region,
    # spacing,
    # registration ("g" for gridline or "p" for pixel),
)
data
# Out:
# <xarray.DataArray 'z' (y: 1036, x: 1046)> Size: 4MB
# array([[-4912.102 , -4875.639 , -4813.1895, ..., -3779.0745, -3804.4434,
#         -3824.2087],
#        [-4948.12  , -4918.801 , -4826.1426, ..., -3770.9395, -3797.8574,
#         -3819.2559],
#        [-5010.9062, -4958.0786, -4846.2485, ..., -3759.5405, -3845.0251,
#         -3812.4456],
#        ...,
#        [-4720.409 , -4718.921 , -4717.584 , ...,        nan,        nan,
#                nan],
#        [-4730.8477, -4728.98  , -4727.125 , ...,        nan,        nan,
#                nan],
#        [-4739.7173, -4737.3057, -4734.852 , ...,        nan,        nan,
#                nan]], dtype=float32)
# Coordinates:
#   * x        (x) float64 8kB -3.328e+06 -3.322e+06 ... 1.892e+06 1.898e+06
#   * y        (y) float64 8kB -3.328e+06 -3.322e+06 ... 1.842e+06 1.848e+06
# Attributes:
#     long_name:     z
#     actual_range:  [-8503.13378906    78.26931763]

# %%
_ = utils.get_grid_info(data, print_info=True)
# Out:
# grid spacing: 5000.0 m
# grid region: (-3330000.0, 1900000.0, -3330000.0, 1850000.0)
# grid zmin: -8503.13378906
# grid zmax: 78.269317627
# grid registration: p

# %%
fig = maps.plot_grd(
    data,
    title="Basement Topography",
    coast=True,
)

fig.show()
