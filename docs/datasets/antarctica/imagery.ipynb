# %% [markdown]
# # Landsat Image Mosaic of Antarctica (LIMA)
#
# **Description:** Satellite imagery of Antarctica
#
# **Dataset DOI:** N.A.
#
# **Associated paper:** The Landsat Image Mosaic of Antarctica. DOI: 10.1016/j.rse.2006.12.020

# %%
# %%capture
# %load_ext autoreload
# %autoreload 2

from polartoolkit import fetch, maps, regions

# %%
data = fetch.modis_moa()
data
# Out:
# '/home/mdtanker/.cache/pooch/polartoolkit/imagery/moa750_2009_hp1_v02.0.tif'

# %%
fig = maps.plot_grd(
    data,
    region=regions.antarctica,
    image=True,
    title="LIMA imagery",
    coast=True,
    # cmap=
)
fig.show()
# Out:
# /home/mdtanker/miniforge3/envs/polartoolkit/lib/python3.11/site-packages/pygmt/clib/session.py:620: RuntimeWarning: The definition of geographic CRS EPSG:4326 got from GeoTIFF keys is not the same as the one from the EPSG registry, which may cause issues during reprojection operations. Set GTIFF_SRS_SOURCE configuration option to EPSG to use official parameters (overriding the ones from GeoTIFF keys), or to GEOKEYS to use custom values from GeoTIFF keys and drop the EPSG code.
#   status = c_call_module(
# Warning 1: The definition of geographic CRS EPSG:4326 got from GeoTIFF keys is not the same as the one from the EPSG registry, which may cause issues during reprojection operations. Set GTIFF_SRS_SOURCE configuration option to EPSG to use official parameters (overriding the ones from GeoTIFF keys), or to GEOKEYS to use custom values from GeoTIFF keys and drop the EPSG code.
# ...
