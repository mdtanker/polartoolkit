# %% [markdown]
# # Create subplots

# %% [markdown]
# Import the modules

# %%
# %%capture
# %load_ext autoreload
# %autoreload 2

from antarctic_plots import maps, fetch

# %% [markdown]
# Define the region of interest and fetch the datasets

# %%
# %%capture

region = [-1800e3, -1000e3, -1200e3, -700e3]

bed = fetch.bedmachine(layer="bed", region=region)
gravity = fetch.gravity(version="antgg-update", anomaly_type="FA", region=region)

# %%
fig = maps.plot_grd(
    bed,
    fig_height=10,
    grd2cpt=True,
    cmap="batlowW",
    coast=True,
    coast_pen="1p,black",
    cbar_label="Bedmachine bed elevation",
    cbar_unit="m",
    gridlines=True,
    x_spacing=8,
    y_spacing=4,
    hist=True,
)

fig = maps.plot_grd(
    gravity,
    fig_height=10,
    grd2cpt=True,
    cmap="viridis",
    coast=True,
    coast_pen="1p,black",
    cbar_label="Free-air gravity",
    cbar_unit="mGal",
    origin_shift="yshift",
    yshift_amount=1.2,  # need extra shift due to colorbar
    fig=fig,
    inset=True,
    inset_pos="TR",
    gridlines=True,
    x_spacing=8,
    y_spacing=4,
    hist=True,
)

# save the figure to use in the Gallery examples
fig.savefig("outputs/subplots.png")

# display the figure
fig.show()
# Out:
# gmtset [WARNING]: Representation of font type not recognized. Using default.
# mapproject [WARNING]: For a UTM or TM projection, your region -1800000.0/-1000000.0/-1200000.0/-700000.0 is too large to be in degrees and thus assumed to be in meters
# colorbar [WARNING]: For a UTM or TM projection, your region -1800000.0/-1000000.0/-1200000.0/-700000.0 is too large to be in degrees and thus assumed to be in meters
# returning original grid
# gmtset [WARNING]: Representation of font type not recognized. Using default.
# mapproject [WARNING]: For a UTM or TM projection, your region -1800000.0/-1000000.0/-1200000.0/-700000.0 is too large to be in degrees and thus assumed to be in meters
# mapproject [WARNING]: For a UTM or TM projection, your region -1800000.0/-1000000.0/-1200000.0/-700000.0 is too large to be in degrees and thus assumed to be in meters
# colorbar [WARNING]: For a UTM or TM projection, your region -1800000.0/-1000000.0/-1200000.0/-700000.0 is too large to be in degrees and thus assumed to be in meters
# returning original grid
