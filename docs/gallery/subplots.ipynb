# %% [markdown]
# # Create subplots

# %%
# %%capture 
# %load_ext autoreload
# %autoreload 2

from antarctic_plots import maps, fetch

# %%
region = [-1800e3, -1000e3, -1200e3, -700e3]

bed = fetch.bedmachine(layer="bed")
gravity = fetch.gravity(type="FA", region=region)

fig = maps.plot_grd(
    bed,
    plot_region=region,
    grd2cpt=True,
    cmap="batlowW",
    coast=True,
    cbar_label="Bedmachine bed elevation (m)",
    grid_lines=True,
)

fig = maps.plot_grd(
    gravity,
    plot_region=region,
    grd2cpt=True,
    cmap="viridis",
    coast=True,
    cbar_label="Free-air gravity (mGal)",
    origin_shift="yshift",
    fig=fig,
    inset=True,
    inset_pos="TR",
    grid_lines=True,
)

# save the figure to use in the Gallery examples
fig.savefig('outputs/subplots.png')

# display the figure
fig.show()
# Out:
# gmtset [WARNING]: Representation of font type not recognized. Using default.
# gmtset [WARNING]: Representation of font type not recognized. Using default.
