# %% [markdown]
# # Create subplots

# %% [markdown]
# Import the modules

# %%
# %%capture
# %load_ext autoreload
# %autoreload 2

from antarctic_plots import maps, fetch

# %% [markdown]
# Define the region of interest and fetch the datasets

# %%
region = [-1800e3, -1000e3, -1200e3, -700e3]

bed = fetch.bedmachine(layer="bed")
gravity = fetch.gravity(version="antgg-update", anomaly_type="FA")
# Out:
# returning original grid
# returning original grid

# %%
fig = maps.plot_grd(
    bed,
    fig_height=10,
    region=region,
    grd2cpt=True,
    cmap="batlowW",
    coast=True,
    coast_pen="1p,black",
    cbar_label="Bedmachine bed elevation",
    cbar_unit="m",
    gridlines=True,
    x_spacing=8,
    y_spacing=4
)

fig = maps.plot_grd(
    gravity,
    fig_height=10,
    region=region,
    grd2cpt=True,
    cmap="viridis",
    coast=True,
    coast_pen="1p,black",
    cbar_label="Free-air gravity",
    cbar_unit="mGal",
    origin_shift="yshift",
    fig=fig,
    inset=True,
    inset_pos="TR",
    gridlines=True,
    x_spacing=8,
    y_spacing=4
)

# save the figure to use in the Gallery examples
fig.savefig("outputs/subplots.png")

# display the figure
fig.show()
# Out:
# gmtset [WARNING]: Representation of font type not recognized. Using default.
# gmtset [WARNING]: Representation of font type not recognized. Using default.
