# %% [markdown]
# # Add additional PyGMT methods

# %%
# %%capture 
# %load_ext autoreload
# %autoreload 2

from antarctic_plots import maps, fetch

# %%
imagery = fetch.imagery()

region = [150e3, 550e3, -1350e3, -1100e3]

fig = maps.plot_grd(
    imagery,
    plot_region=region,
    image=True,
    inset=True,
    title="LIMA imagery",
    grid_lines=True,
    x_annots=10,  # plot 10 degree longitude lines
    y_annots=2,  # plot 2 degree latitude lines
)

# use standard PyGMT methods
# add surface elevation contours
surface = fetch.bedmachine(layer="surface", region=region, spacing=1e3)
fig.grdcontour(grid=surface, interval=750, pen="thick,red")

# save the figure to use in the Gallery examples
fig.savefig('outputs/extend_pygmt.png')

# show the figure
fig.show()
# Out:
# c:\Users\matthewt\AppData\Local\miniforge3\envs\antarctic_plots\lib\site-packages\xarray\backends\cfgrib_.py:29: UserWarning: Failed to load cfgrib - most likely there is a problem accessing the ecCodes library. Try `import cfgrib` to get the full error message
#   warnings.warn(
# gmtset [WARNING]: Representation of font type not recognized. Using default.
# c:\Users\matthewt\AppData\Local\miniforge3\envs\antarctic_plots\lib\site-packages\xarray\backends\plugins.py:64: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)
# psconvert [ERROR]: Registry registered C:\Program Files (x86)\GPLGS\gswin32c.exe does not exist. Resorting to the one provided in GMT.
# psconvert [ERROR]: Registry registered C:\Program Files (x86)\GPLGS\gswin32c.exe does not exist. Resorting to the one provided in GMT.
