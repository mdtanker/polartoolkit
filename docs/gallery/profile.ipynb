# %% [markdown]
# # Sample and plot profile

# %%
# %%capture
# %load_ext autoreload
# %autoreload 2

from polartoolkit import fetch, profile

# %%
fig, df_layers, df_data = profile.plot_profile(
    method="shapefile",
    shapefile=fetch.sample_shp("Disco_deep_transect"),
)
fig.show()
