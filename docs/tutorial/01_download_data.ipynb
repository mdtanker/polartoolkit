# %% [markdown]
# # Download polar data
# One of the main functionalities of PolarToolkit is to download datasets commonly used for polar research. There is a very simple demonstration of how this works. We will download a grid file, a shapefile, and some point data.

# %% [markdown]
# Import the `fetch` module of PolarToolkit

# %%
from polartoolkit import fetch

# %% [markdown]
# Download bathymetry and bed elevation data from IBCSO. The first time you call this function, it will download the IBCSO netcdf (`.nc`) file, reproject it to EPSG 3031 (a mapping projection useful for Antarctica) and save the reprojected file to your computer. Subsequent calls to the function will find this reprojected file and load it for you, without re-downloading. This function returns the grid loaded as an xarray dataarray.

# %%
grid = fetch.ibcso(layer="bed")
grid
# Out:
# <xarray.DataArray 'z' (y: 11200, x: 11200)> Size: 502MB
# array([[-2444.2244, -2454.7163, -2470.1309, ..., -3904.6677, -3928.252 ,
#         -3942.8115],
#        [-2432.8696, -2442.8757, -2456.6677, ..., -3912.2058, -3931.9822,
#         -3947.1372],
#        [-2417.4812, -2425.4983, -2437.3916, ..., -3928.6038, -3945.2407,
#         -3958.4075],
#        ...,
#        [-4342.287 , -4354.4634, -4364.544 , ..., -3939.1323, -3936.5476,
#         -3934.6245],
#        [-4401.358 , -4394.68  , -4409.5806, ..., -3943.5486, -3940.646 ,
#         -3938.08  ],
#        [-4536.0093, -4499.3096, -4456.6895, ..., -3948.989 , -3944.7522,
#         -3940.728 ]], dtype=float32)
# Coordinates:
#   * x        (x) float64 90kB -2.8e+06 -2.799e+06 ... 2.799e+06 2.8e+06
#   * y        (y) float64 90kB -2.8e+06 -2.799e+06 ... 2.799e+06 2.8e+06
# Attributes:
#     long_name:     z
#     actual_range:  [-6321.07080078  4723.67041016]

# %% [markdown]
# There are also some shapefiles available to download. Here we will download a shapefile (`.shp`) of the Greenland grounding line. In this case, the function returns the path to the download shapefile.

# %%
filepath = fetch.groundingline(version="measures-greenland")
filepath
# Out:
# '/home/mdtanker/.cache/pooch/polartoolkit/shapefiles/measures/mog100_geus_coastline_v02.shp'

# %% [markdown]
# There are also some point datasets available. Below we will download the individual point data of topography from Bedmap1 as a `.csv` file and automatically load it into a pandas dataframe.

# %%
df = fetch.bedmap_points(version="bedmap1")
df
# Out:
#          trajectory_id  longitude (degree_east)  latitude (degree_north)  \
# 0                    1                  4.44900                -75.62300
# 1                    2                  4.43800                -75.62100
# 2                    3                  4.42500                -75.61900
# 3                    4                  4.42000                -75.61900
# 4                    5                  4.40700                -75.61700
# ...                ...                      ...                      ...
# 1905045        1905046                -53.79618                -83.97787
# 1905046        1905047                -53.81247                -83.98000
# 1905047        1905048                -53.88616                -83.98947
# 1905048        1905049                -53.90617                -83.99211
# 1905049        1905050                -53.92110                -83.99413
#
#          surface_altitude (m)  land_ice_thickness (m)  bedrock_altitude (m)  \
# 0                         NaN                  2650.0                   NaN
# 1                         NaN                  2628.0                   NaN
# 2                         NaN                  2620.0                   NaN
# 3                         NaN                  2635.0                   NaN
# 4                         NaN                  2646.0                   NaN
# ...                       ...                     ...                   ...
# 1905045                1350.0                   779.0                   NaN
# 1905046                1346.0                   756.0                   NaN
# 1905047                1342.0                   941.0                   NaN
# 1905048                1343.0                   705.0                   NaN
# 1905049                1341.0                   581.0                   NaN
#
#                      x             y
# 0        121788.567945  1.565282e+06
# 1        121505.125021  1.565526e+06
# 2        121166.937514  1.565773e+06
# 3        121030.297575  1.565784e+06
# 4        120691.982493  1.566031e+06
# ...                ...           ...
# 1905045 -528450.753601  3.868216e+05
# 1905046 -528373.430978  3.865343e+05
# 1905047 -528036.700836  3.852464e+05
# 1905048 -527938.815436  3.848925e+05
# 1905049 -527861.239735  3.846254e+05
#
# [1905050 rows x 8 columns]
