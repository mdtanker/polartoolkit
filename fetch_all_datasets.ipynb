# %%
# %load_ext autoreload
# %autoreload 2
from polartoolkit import fetch, regions

# %%
for n in ["Disco_deep_transect", "Roosevelt_Island"]:
    fetch.sample_shp(n)

# %%
fetch.mass_change(hemisphere="south")

# %%
fetch.basal_melt()

# %%
variables = [
    "max",
    "min",
    "flow",
    "viscosity",
]
for v in variables:
    fetch.buttressing(version=v)

# %%
fetch.ice_vel(hemisphere="south", spacing=450)

# %%
fetch.ice_vel(hemisphere="south", spacing=5e3)

# %%
fetch.ice_vel(hemisphere="north")

# %%
fetch.modis(hemisphere="south", version="125m")

# %%
fetch.modis(hemisphere="south", version="750m")

# %%
fetch.modis(hemisphere="north", version="100m")

# %%
fetch.modis(hemisphere="north", version="500m")

# %%
fetch.imagery()

# %%
fetch.antarctic_bed_type(region=regions.minna_bluff)

# %%
fetch.geomap()

# %%
versions = [
    "depoorter-2013",
    "measures-v2",
    "BAS",
    "measures-greenland",
]
for v in versions:
    fetch.groundingline(version=v)

# %%
versions = [
    "Coastline",
    "Basins_Antarctica",
    "Basins_IMBIE",
    "IceBoundaries",
    "IceShelf",
    "Mask",
]
for v in versions:
    fetch.antarctic_boundaries(version=v)

# %%
versions = [
    "ANTASed",
    "tankersley-2022",
    "lindeque-2016",
    "GlobSed",
]
for v in versions:
    fetch.sediment_thickness(version=v)

# %%
fetch.ibcso_coverage(region=regions.siple_dome)

# %%
fetch.ibcso(layer="surface", spacing=500)

# %%
fetch.ibcso(layer="surface", spacing=5e3)

# %%
fetch.ibcso(layer="bed", spacing=5e3)

# %%
fetch.ibcso(layer="bed", spacing=500)

# %%
fetch.bedmachine(hemisphere="south", spacing=500, layer="bed")

# %%
fetch.bedmachine(hemisphere="south", spacing=5e3, layer="bed")

# %%
layers = [
    "bed",
    "dataid",
    "errbed",
    "firn",
    "geoid",
    "mask",
    "source",
    "surface",
    "ice_thickness",
    "icebase",
]
for layer in layers:
    fetch.bedmachine(hemisphere="south", spacing=5e3, layer=layer)

# %%
fetch.bedmachine(hemisphere="north", spacing=150, layer="bed")

# %%
fetch.bedmachine(hemisphere="north", spacing=5e3, layer="bed")

# %%
layers = [
    "bed",
    "dataid",
    "errbed",
    "geoid",
    "mask",
    "source",
    "surface",
    "ice_thickness",
    "icebase",
]
for layer in layers:
    print(layer)
    fetch.bedmachine(hemisphere="north", spacing=5e3, layer=layer)

# %%
fetch.bedmap_points(version="bedmap1", region=regions.siple_dome)

# %%
fetch.bedmap_points(version="bedmap2", region=regions.siple_dome)

# %%
fetch.bedmap_points(version="bedmap3", region=regions.siple_dome)

# %%
layers = [
    "surface",
    "icebase",
    "bed",
    "ice_thickness",
    "water_thickness",
    "bed_uncertainty",
    "ice_thickness_uncertainty",
    "mask",
]
for layer in layers:
    print(layer)
    fetch.bedmap3(hemisphere="south", spacing=5e3, layer=layer)
    fetch.bedmap3(hemisphere="south", spacing=500, layer=layer)

# %%
layers = [
    "bed",
    "coverage",
    "grounded_bed_uncertainty",
    "icemask_grounded_and_shelves",
    "lakemask_vostok",
    "rockmask",
    "surface",
    "ice_thickness",
    "ice_thickness_uncertainty",
    "gl04c_geiod_to_WGS84",
    "icebase",
    "water_thickness",
]
for layer in layers:
    print(layer)
    fetch.bedmap2(hemisphere="south", spacing=5e3, layer=layer)
    fetch.bedmap2(hemisphere="south", spacing=1e3, layer=layer)

# %%
fetch.rema(version="1km")
fetch.rema(version="500m")

# %%
fetch.deepbedmap()

# %%
anomaly = [
    "FA",
    "DG",
    "BA",
    "Err",
]
for a in anomaly:
    fetch.gravity(version="antgg-2021", anomaly_type=a, hemisphere="south")

# %%
versions = [
    "antgg",
    "eigen",
]
for v in versions:
    fetch.gravity(version=v, hemisphere="south")

# %%
fetch.gravity(version="eigen", hemisphere="north")

# %%
fetch.etopo(hemisphere="south")
fetch.etopo(hemisphere="north")

# %%
fetch.geoid(hemisphere="south")
fetch.geoid(hemisphere="north")

# %%
versions = [
    "admap1",
    "admap2",
    "admap2_gdb",
    "LCS-1",
]
for v in versions:
    fetch.magnetics(version=v, hemisphere="south")

# %%
fetch.magnetics(version="LCS-1", hemisphere="north")

# %%
versions = [
    "an-2015",
    "martos-2017",
    "shen-2020",
    "burton-johnson-2020",
    "losing-ebbing-2021",
    "aq1",
]
for v in versions:
    fetch.ghf(version=v)
    if v == "burton-johnson-2020":
        fetch.ghf(version=v, points=True)

# %%
versions = [
    "stal-2020",
]
for v in versions:
    fetch.gia(version=v)

# %%
versions = [
    "shen-2018",
    "an-2015",
]
for v in versions:
    fetch.crustal_thickness(version=v)

# %%
versions = [
    "shen-2018",
    "an-2015",
    "pappa-2019",
]
for v in versions:
    fetch.moho(version=v)
